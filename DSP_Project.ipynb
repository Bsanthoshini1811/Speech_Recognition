# %% [markdown]
# # Title: Accents & Agnostic Speech Transcription Model for User Enhanced Accessibility.
#
# ## Team - Titans Alliance.
#
# ### Introduction.
#
# In today's digital age, education has surpassed the boundaries of traditional classrooms, thanks to the proliferation of e-learning platforms. However, in the middle of this transformation, a significant challenge persists ensuring that educational content is accessible to learners of diverse backgrounds and abilities. Imagine trying to learn from an online lecture, only to be hindered by accents or dialects that make understanding difficult. This is the reality faced by many learners worldwide. Our project, driven by a passion for inclusivity and accessibility in education, aims to tackle this challenge. By developing an innovative speech transcription model, we aspire to break down barriers and empower learners from all walks of life to engage effectively with educational content. To achieve our goal, we start by converting audio files into Mel-frequency cepstral coefficients (MFCCs), a technique widely used in audio signal processing. MFCCs allow us to extract essential features from the sound spectrum, enabling our model to understand spoken language more effectively. Additionally, we perform a train-test split to ensure that our model is trained on a diverse dataset while also being evaluated on unseen data.
#
# We don't stop there. We rigorously evaluate our model's performance using metrics such as Loss function and accuracy between the predicted outputs and actual label, we can further decode the outputs using decode function but that part is left out due to constraint in computation resources, also these output sequences require preprocessing that can be changed to texts but now the outputs are in the form of sequences so we transformed our labels into the sequences further details will be explained below in the Notebook. These metrics allow us to assess how accurately our model transcribes speech and how well it generalizes to new data. We compare the performance of different models, including Recurrent Neural Networks (RNN), Long Short-Term Memory (LSTM), and Gated Recurrent Unit (GRU), to identify the most effective approach.
#
# Ultimately, our goal is to select the model that achieves the highest accuracy. By doing so, we can pave the way for a more inclusive and accessible future in ed-tech platforms, where every learner has the opportunity to thrive. So, let's get into it!

# %% [markdown]
# ### 0. Import Required Packages

# %%
pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.3-py2.py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.10/site-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from SpeechRecognition) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (2024.2.2)
# Downloading SpeechRecognition-3.10.3-py2.py3-none-any.whl (32.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 48.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (3.2.1)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras) (13.7.0)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras) (3.10.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras) (0.11.0)
# Requirement already satisfied: ml-dtypes in /opt/conda/lib/python3.10/site-packages (from keras) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from optree->keras) (4.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install resampy
# Out:
# Collecting resampy
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from resampy) (1.26.4)
# Requirement already satisfied: numba>=0.53 in /opt/conda/lib/python3.10/site-packages (from resampy) (0.58.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.53->resampy) (0.41.1)
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 40.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: resampy
# Successfully installed resampy-0.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade librosa
# Out:
# Requirement already satisfied: librosa in /opt/conda/lib/python3.10/site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /opt/conda/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pooch>=1.0->librosa) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2024.2.2)

# %%
from sklearn.feature_extraction.text import CountVectorizer
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import librosa
import sklearn
import nltk
import tarfile
import os
import resampy
import speech_recognition as sr
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2024-05-02 12:11:08.998980: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-02 12:11:08.999100: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-02 12:11:09.186144: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### 1. Load Data.
#
# In this step we load the data into our Notebook our data is audio files downloaded from Mozilla Common Voice website, which contains the audio files where the speakers record speaking a phrase in english and we are going to convert this audio files into numeric inputs, but at first as the files are in `.mp3` format so we convert them into Mel-Frequency Cepstral Coefficients (MFCC) which measure the way humar ear perceives the sounds.

# %%
# Step 1: Load Audio Files
data_dir = "/kaggle/input/audiodata/clips"
file_paths = [os.path.join(data_dir, file) for file in os.listdir(data_dir) if file.endswith('.mp3')]

# %% [markdown]
# ### 2. Data Preprocessing.

# %% [markdown]
# Now, that we have converted our audio files into MFCCs, now we are going to create labels that is our target variables by using SpeechRecognition module by Google, which transcribes the speech from the audio files but for that at first we have to change the format as this module can recognize `.wav` files but not the files with the extension `.mp3`. So, let's do it.

# %%
def preprocess_audio(audio_file):
    audio, sr = librosa.load(audio_file, sr=6000, mono=True, res_type='kaiser_fast')
    mfccs = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=13)
    return mfccs

# %%
preprocess =  [preprocess_audio(file_path) for file_path in file_paths]

# %%
# Install ffmpeg (if not already installed)
# !apt-get install ffmpeg

# Path to the folder containing the MP3 files
mp3_folder = "/kaggle/input/audiodata/clips"

# Path to the folder where you want to save the converted WAV files
wav_folder = "/kaggle/working/wav"

# Create the output folder if it doesn't exist
if not os.path.exists(wav_folder):
    os.makedirs(wav_folder)

# Iterate over each file in the MP3 folder
for mp3_file in os.listdir(mp3_folder):
    # Check if the file is an MP3 file
    if mp3_file.endswith('.mp3'):
        # Construct the paths for the input and output files
        mp3_path = os.path.join(mp3_folder, mp3_file)
        wav_path = os.path.join(wav_folder, os.path.splitext(mp3_file)[0] + '.wav')

        # Convert MP3 to WAV using ffmpeg
        # !ffmpeg -i "$mp3_path" "$wav_path"
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 65 not upgraded.
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x5654118dfb40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_33152312.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:08.82, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_33152312.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     551kB time=00:00:08.82 bitrate= 512.1kbits/s speed= 541x
# video:0kB audio:551kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013818%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x5c80d6345b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34028573.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:04.10, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34028573.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     257kB time=00:00:04.10 bitrate= 512.2kbits/s speed= 910x
# video:0kB audio:256kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.029697%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x57aaaf594b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34894803.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:05.22, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34894803.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     326kB time=00:00:05.22 bitrate= 512.1kbits/s speed=1.04e+03x
# video:0kB audio:326kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.023348%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x55e3afa3ab40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_33158260.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:06.55, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_33158260.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     410kB time=00:00:06.55 bitrate= 512.1kbits/s speed=1.13e+03x
# video:0kB audio:410kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.018601%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x565b9c27ab40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34893951.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:06.12, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34893951.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     383kB time=00:00:06.12 bitrate= 512.1kbits/s speed=1.07e+03x
# video:0kB audio:382kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.019914%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x57afb3e8bb40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_33540443.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:04.14, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_33540443.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     259kB time=00:00:04.14 bitrate= 512.2kbits/s speed= 982x
# video:0kB audio:259kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.029438%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x5bf793cf0b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_33162196.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:05.44, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_33162196.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     340kB time=00:00:05.43 bitrate= 512.1kbits/s speed= 997x
# video:0kB audio:340kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.022420%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x56da9b2e3b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34893765.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:05.94, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34893765.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     371kB time=00:00:05.94 bitrate= 512.1kbits/s speed=1.09e+03x
# video:0kB audio:371kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.020518%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x5c53b9d9db40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34894775.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:06.80, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34894775.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     425kB time=00:00:06.80 bitrate= 512.1kbits/s speed=1.21e+03x
# video:0kB audio:425kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.017912%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x55ed77f23b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34893834.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:04.18, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34893834.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     261kB time=00:00:04.17 bitrate= 512.1kbits/s speed=1e+03x
# video:0kB audio:261kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.029185%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x560e61725b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34893713.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:05.40, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34893713.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     338kB time=00:00:05.40 bitrate= 512.1kbits/s speed=1.04e+03x
# video:0kB audio:338kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.022569%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x58d11d779b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34028726.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:04.21, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34028726.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     263kB time=00:00:04.21 bitrate= 512.1kbits/s speed=1.02e+03x
# video:0kB audio:263kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.028935%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x5d37c23c3b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34893907.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:07.67, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34893907.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     479kB time=00:00:07.66 bitrate= 512.1kbits/s speed=1.1e+03x
# video:0kB audio:479kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.015894%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x565ac1873b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34028380.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:06.05, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34028380.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     378kB time=00:00:06.04 bitrate= 512.1kbits/s speed=1.12e+03x
# video:0kB audio:378kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.020151%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x5969b5260b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34894123.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:07.96, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34894123.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     497kB time=00:00:07.95 bitrate= 512.1kbits/s speed= 985x
# video:0kB audio:497kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.015319%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x57bf5f5d4b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34894714.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:03.78, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34894714.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     236kB time=00:00:03.78 bitrate= 512.2kbits/s speed= 919x
# video:0kB audio:236kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.032242%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x57667e1f5b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_33540280.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:06.77, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_33540280.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     423kB time=00:00:06.76 bitrate= 512.1kbits/s speed=1.17e+03x
# video:0kB audio:423kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.018008%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x5c2238471b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34894124.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:04.86, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34894124.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     304kB time=00:00:04.86 bitrate= 512.1kbits/s speed= 856x
# video:0kB audio:304kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.025077%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     412kB time=00:00:06.58 bitrate= 512.1kbits/s speed=1.23e+03x
# video:0kB audio:412kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.018500%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x57c767ac9b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34894770.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:05.69, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34894770.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     356kB time=00:00:05.68 bitrate= 512.1kbits/s speed=1.07e+03x
# video:0kB audio:356kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.021427%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x59b2de65db40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34028575.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:04.79, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34028575.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     299kB time=00:00:04.78 bitrate= 512.1kbits/s speed=1.01e+03x
# video:0kB audio:299kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.025454%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x56ffde296b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34893952.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:05.40, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34893952.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     338kB time=00:00:05.40 bitrate= 512.1kbits/s speed=1.08e+03x
# video:0kB audio:338kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.022569%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x5a593f100b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_33159397.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:05.69, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_33159397.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     356kB time=00:00:05.68 bitrate= 512.1kbits/s speed=1.08e+03x
# video:0kB audio:356kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.021427%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x59410f214b40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_34028724.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:04.03, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_34028724.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     252kB time=00:00:04.03 bitrate= 512.2kbits/s speed=1.03e+03x
# video:0kB audio:252kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.030227%
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mp3 @ 0x57a25b32bb40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/audiodata/clips/common_voice_en_33152311.mp3':
#   Metadata:
#     encoder         : Lavf57.56.101
#   Duration: 00:00:09.58, start: 0.000000, bitrate: 48 kb/s
#     Stream #0:0: Audio: mp3, 32000 Hz, mono, fltp, 48 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav/common_voice_en_33152311.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     599kB time=00:00:09.57 bitrate= 512.1kbits/s speed=1.23e+03x
# video:0kB audio:598kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012727%

# %% [markdown]
# Since we have changed the format, now it's time to transcribe them using SpeechRecognition

# %%
def transcribe_wav_files(wav_folder):
    transcripts = []
    recognizer = sr.Recognizer()

    # Iterate over each WAV file in the folder
    for wav_file in os.listdir(wav_folder):
        if wav_file.endswith('.wav'):
            # Construct the path to the WAV file
            wav_path = os.path.join(wav_folder, wav_file)

            # Load the WAV file
            with sr.AudioFile(wav_path) as source:
                audio_data = recognizer.record(source)

                # Perform speech recognition
                try:
                    transcript = recognizer.recognize_google(audio_data)
                    transcripts.append(transcript)
                except sr.UnknownValueError:
                    # Handle unrecognized speech
                    transcripts.append("Recognition failed for file: {}".format(wav_file))
                except sr.RequestError as e:
                    # Handle API request error
                    transcripts.append("Could not request results for file: {} (error: {})".format(wav_file, e))

    return transcripts

# %%
transcripts = transcribe_wav_files(wav_folder)
print(transcripts)
# Out:
# ['bunny bunny bunny at Herbert Lehman High School in the Bronx', 'he plays for Managua', 'the hotel provides good views of the local Lake and the alveolar Alps', 'this must be an incredibly distressing time for them', 'Murray is married to Melissa and has two children', 'he joined Damian Blake and Neil Clark as new members of Letterkenny Town Council', 'she began gymnastics when she was 8 years old', 'lighter yellowish', 'me Teresa Darcy miento ISTA contribution', 'they suggested to her the writing of the life of Edgeworth', 'smolensky began his business activities on the black market of the so-called Shadow economy', 'the team would play the next five seasons decked all in blue', 'Insurance contributed to developing and disappointing King friendly safe for sex Technologies', 'driving 1 the series', 'it is native to Tropical Africa Trinidad and tropical Central and South America', 'Nancy unit turned Southwest word while lion Rock turned Eastward', 'he also became renowned for his off-air pranks and intellectually challenging quizzes', 'it is also an exceptionally good one', 'the exterior structural members are clawed in bronze and black Canadian granite', 'also saw does legislative deputy chief for Harris County', 'her advisor was professor John Rowe', 'he also participated in National and international scientific seminars', 'she also served on the New Mexico Humanities Council Bicentennial Commission', 'the last cobbled part of the street passes through the Carlsberg neighborhood', 'the music video was generally praised by reviews', 'Hazen supported the clearances but raised concerns about the process', 'it was one of the most viewed television programs in Nepal', 'after this election Roberts began to consider forming a new political party', 'hello beautiful I like I did it again', 'and this is exactly what his family left him with', 'convictions were appealed to the Supreme Court', 'the name great was given to him by his father', 'it administrative Center is the city of Nelson North Dakota', 'the two would later maintained a lifelong friendship', 'Annapolis Mall of the 2011 to collaboration with Nazi Germany', 'it is called the Holy Trinity and Saints', 'Frank grew up in the Brixton area of London', 'her research focused on radiation health effects', 'the straw poll was not binding and did not involve the entire faculty', "she's based in the United States", 'the small village was situated to the northwest of Virginia', 'the current coach is Jesse White', 'the terrorist group Eragon claimed responsibility for the bombing', 'Elijah pubescent similar to that of pronotum', 'Rossi has explored the creation of metallic nanoparticles for heterogeneous catalysis', 'he did not appear for the promotion again until 2 years later', 'the club Underwood major Renovations following the fire', 'she began her autobiography shortly thereafter', 'find graduated from Windsor High School', 'the ovate aperture is dirty white', "Apple talked over coax cable was the way macintosh's communicated", 'she was the pioneer of opening master and doctoral programs on Turkish music', 'the chef de Michonne was Jesse Tate', 'attribute from our hearts to theirs', 'how physical condition has not improved since then', 'Osmos gulenko recalls quoting an anonymous Soldier these fascists woke up after they hibernated', 'he graduated from Illinois College and started reading Law', 'mercury has been linked to developmental deficits in children and neurologic symptoms', 'Sharma was born and brought up in Delhi', 'again being knocked out in the first round of the tournament', 'it falls within the Birmingham erdington parliamentary constituency', 'from his early childhood txl in stat', 'interesante Christians', 'one of the people she employed with William Henry Hereford', 'face value was released to critical acclaim', 'she is also active within the American Psychological Association', 'these floats feature scenes from Hindu mythology', 'he also played Four matches for Go ...

# %% [markdown]
# Now, we are going to preprocess our data so that we can use that to train our models LSTM, GRU and RNN. In preprocessing to ensure the feature(mfcc coefficients) and target (labels/transcripts) are having the same dimensionality, we are going to do some padding for both the target and feature variable so, let's do it

# %%
audio_folder = "/kaggle/working/wav"

# %%
audio_dir = os.listdir(audio_folder)

# %%
file_transcript_mapping = {}

# %%
# Iterate over each index and its corresponding transcript
for i in range(len(file_paths)):
    # Construct the full file path
    full_audio_path = os.path.join(audio_folder, audio_dir[i])
    # Add the mapping to the dictionary
    file_transcript_mapping[full_audio_path] = transcripts[i]

# Access transcript for a specific audio file
specific_audio_file = "/kaggle/working/wav/common_voice_en_34893938.wav"
print("Transcript for", specific_audio_file, ":", file_transcript_mapping[specific_audio_file])
# Out:
# Transcript for /kaggle/working/wav/common_voice_en_34893938.wav : Apple talked over coax cable was the way macintosh's communicated

# %%
transcripts = list(file_transcript_mapping.values())

# %%
len(transcripts)
# Out:
# 470

# %%
# Find the maximum length of MFCC array
max_mfcc_length = max(len(mfcc) for mfcc in preprocess)

# Pad MFCC features to have the same time steps
preprocess_padded = [np.pad(mfcc, ((0, max_mfcc_length - len(mfcc)), (0, 0)), mode='constant') for mfcc in preprocess]

# %%
shapes = [np.array(p).shape for p in preprocess_padded]
print(shapes[:5])  # This will show the shape of each element
# Out:
# [(13, 104), (13, 49), (13, 62), (13, 77), (13, 72)]

# %%
# Find the maximum length in the second dimension
max_length = max(p.shape[1] for p in preprocess_padded)

# %%
max_length
# Out:
# 120

# %%
# Pad each array to have the same second dimension length
padded_arrays = [np.pad(p, ((0, 0), (0, max_length - p.shape[1])), 'constant', constant_values=0) for p in preprocess_padded]

# Now convert to a single numpy array
uniform_array = np.stack(padded_arrays)

print("Shape of the unified array:", uniform_array.shape)
# Out:
# Shape of the unified array: (470, 13, 120)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# Tokenize at the word level
word_tokenizer = Tokenizer(filters='', lower=False, split=' ')
word_tokenizer.fit_on_texts(transcripts)  # transcripts should be dataset text

# Convert texts to word-index sequences
word_sequences = word_tokenizer.texts_to_sequences(transcripts)

# Pad sequences to have a uniform length
from tensorflow.keras.preprocessing.sequence import pad_sequences
max_len = 120  # This should be chosen based on data
padded_word_sequences = pad_sequences(word_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
uniform_array.shape
# Out:
# (470, 13, 120)

# %%
padded_word_sequences.shape
# Out:
# (470, 120)

# %%
# Pad each array to have the same second dimension length
padded_arrays = [np.pad(p, ((0, 0), (0, max_length - p.shape[1])), 'constant', constant_values=0) for p in preprocess_padded]

# Now convert to a single numpy array
uniform_array = np.stack(padded_arrays)

print("Shape of the unified array:", uniform_array.shape)
# Out:
# Shape of the unified array: (470, 13, 120)

# %%
# Assuming uniform_array is your MFCC data
X = np.transpose(uniform_array, (0,2,1))

# %%
X.shape
# Out:
# (470, 120, 13)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# Assuming transcripts is your dataset text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(transcripts)

# %% [markdown]
# ### 3. Model Building.

# %% [markdown]
# In this step we are going to build a model that takes in the padded sequences of both the mfcc coefficients and the labels/transcripts converted into numeric sequences and gives output as the sequence which can further be decoded into text and then use the metrics like Word Error rate (WER) to assess the model performance. But as we have a constraint on the resources we are going to chose our model based on the loss function and accuracy of validation set but this model can further be enhanced by interpreting these sequences and we plan to do that further.

# %% [markdown]
# ### Long Short Term Memory(LSTM).

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, TimeDistributed, Dropout
from keras.utils import to_categorical
import numpy as np

num_words = len(word_tokenizer.word_index) + 1

lstm_model = Sequential([
    LSTM(100, return_sequences=True, input_shape=(120, 13)),  # Increased number of units
    Dropout(0.5),  # Adding dropout
    LSTM(100, return_sequences=True),
    TimeDistributed(Dense(num_words, activation='softmax'))
])
lstm_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Assuming padded_transcripts is your encoded and padded transcript data
# and uniform_array is your prepared MFCC feature set shaped 
X = np.array(X)
# y = to_categorical(padded_word_sequences, num_classes=num_words)
X_train, X_test, y_train, y_test = train_test_split(X, padded_word_sequences, test_size = 0.2, random_state = 42)

y_train = to_categorical(y_train, num_classes = num_words)
y_test = to_categorical(y_test, num_classes = num_words)
# Training the model
lstm_model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data= (X_test, y_test))
# Out:
# Epoch 1/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step - accuracy: 0.4900 - loss: 7.3426 - val_accuracy: 0.9229 - val_loss: 5.6665
# Epoch 2/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9225 - loss: 5.0192 - val_accuracy: 0.9229 - val_loss: 2.8081
# Epoch 3/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9228 - loss: 2.2489 - val_accuracy: 0.9229 - val_loss: 0.9987
# Epoch 4/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9234 - loss: 0.8865 - val_accuracy: 0.9229 - val_loss: 0.7538
# Epoch 5/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9242 - loss: 0.7253 - val_accuracy: 0.9229 - val_loss: 0.7329
# Epoch 6/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9236 - loss: 0.7036 - val_accuracy: 0.9229 - val_loss: 0.7084
# Epoch 7/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9244 - loss: 0.6698 - val_accuracy: 0.9229 - val_loss: 0.6733
# Epoch 8/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9231 - loss: 0.6407 - val_accuracy: 0.9229 - val_loss: 0.6341
# Epoch 9/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9242 - loss: 0.6060 - val_accuracy: 0.9229 - val_loss: 0.6243
# Epoch 10/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9242 - loss: 0.5957 - val_accuracy: 0.9244 - val_loss: 0.6141

# %%
y_train.shape
# Out:
# (376, 120, 2016)

# %%
predictions = lstm_model.predict(X_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %% [markdown]
# ###  Gated Recurrent Unit.

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense, TimeDistributed, Dropout

# Construct the model
gru_model = Sequential([
    GRU(200, return_sequences=True, input_shape=(120, 13)),  # Increased number of units
    Dropout(0.5),  # Adding dropout
    GRU(200, return_sequences=True),  # Increased number of units
    TimeDistributed(Dense(num_words, activation='softmax'))
])

# Compile the model
gru_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
gru_model.summary()
# Out:
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 120, 200)       │       129,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 120, 200)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 120, 200)       │       241,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_16             │ (None, 120, 2016)      │       405,216 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 775,416 (2.96 MB)
#  Trainable params: 775,416 (2.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
gru_model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data= (X_test, y_test))
# Out:
# Epoch 1/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 198ms/step - accuracy: 0.6747 - loss: 6.5647 - val_accuracy: 0.9229 - val_loss: 1.4796
# Epoch 2/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9237 - loss: 1.0547 - val_accuracy: 0.9229 - val_loss: 0.6534
# Epoch 3/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9229 - loss: 0.6277 - val_accuracy: 0.9229 - val_loss: 0.6132
# Epoch 4/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9224 - loss: 0.5933 - val_accuracy: 0.9229 - val_loss: 0.5982
# Epoch 5/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9239 - loss: 0.5668 - val_accuracy: 0.9229 - val_loss: 0.5934
# Epoch 6/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9246 - loss: 0.5565 - val_accuracy: 0.9244 - val_loss: 0.5926
# Epoch 7/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9243 - loss: 0.5568 - val_accuracy: 0.9245 - val_loss: 0.5927
# Epoch 8/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9254 - loss: 0.5463 - val_accuracy: 0.9248 - val_loss: 0.5933
# Epoch 9/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9239 - loss: 0.5586 - val_accuracy: 0.9248 - val_loss: 0.5934
# Epoch 10/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9257 - loss: 0.5411 - val_accuracy: 0.9249 - val_loss: 0.5939

# %%
gru_predictions = gru_model.predict(X_train)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step

# %%
gru_evaluation = gru_model.evaluate(X_test, y_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9238 - loss: 0.6023

# %% [markdown]
# ### Recurrent Neural Network.

# %%
from keras.models import Sequential
from keras.layers import RNN, Dense, TimeDistributed, Dropout, SimpleRNNCell


# Construct the model
rnn_model = Sequential([
    RNN(SimpleRNNCell(200), return_sequences=True, input_shape=(120, 13)),  # Increased number of units
    Dropout(0.5),  # Adding dropout
    RNN(SimpleRNNCell(200), return_sequences=True),  # Increased number of units
    TimeDistributed(Dense(num_words, activation='softmax'))
])

# Compile the model
rnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
rnn_model.summary()
# Out:
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rnn (RNN)                       │ (None, 120, 200)       │        42,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 120, 200)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn_1 (RNN)                     │ (None, 120, 200)       │        80,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_17             │ (None, 120, 2016)      │       405,216 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 528,216 (2.01 MB)
#  Trainable params: 528,216 (2.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
rnn_model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data= (X_test, y_test))
# Out:
# Epoch 1/10
#  2/12 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.0130 - loss: 7.5461
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714665076.877828    3611 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24s/step - accuracy: 0.4448 - loss: 6.2547
# W0000 00:00:1714665342.706808    3612 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 570s 27s/step - accuracy: 0.4652 - loss: 6.1405 - val_accuracy: 0.9225 - val_loss: 1.3944
# Epoch 2/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9218 - loss: 1.1028 - val_accuracy: 0.9229 - val_loss: 0.8004
# Epoch 3/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9215 - loss: 0.8007 - val_accuracy: 0.9229 - val_loss: 0.8293
# Epoch 4/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9239 - loss: 0.7780 - val_accuracy: 0.9229 - val_loss: 0.8281
# Epoch 5/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9229 - loss: 0.7749 - val_accuracy: 0.9229 - val_loss: 0.8198
# Epoch 6/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9213 - loss: 0.7695 - val_accuracy: 0.9229 - val_loss: 0.8138
# Epoch 7/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9223 - loss: 0.7452 - val_accuracy: 0.9229 - val_loss: 0.8056
# Epoch 8/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9237 - loss: 0.7201 - val_accuracy: 0.9229 - val_loss: 0.7959
# Epoch 9/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9236 - loss: 0.7080 - val_accuracy: 0.9229 - val_loss: 0.7828
# Epoch 10/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9239 - loss: 0.6909 - val_accuracy: 0.9229 - val_loss: 0.7723

# %%
rnn_predictions = rnn_model.predict(X_train)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step

# %%
rnn_evaluation = rnn_model.evaluate(X_test, y_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9216 - loss: 0.7834

# %% [markdown]
# ### Conclusion.

# %% [markdown]
# The GRU model appears to have achieved the highest accuracy (0.9238) and lowest loss (0.6023) among the RNN, GRU, and LSTM models. However, accuracy and loss metrics alone may not provide a comprehensive understanding of our model performance.
#
# To determine which model is the best choice, consider the following factors:
#
# Performance Metrics: While accuracy and loss are important metrics, consider other performance metrics such as precision, recall, and F1-score, especially if your dataset is imbalanced or if certain classes are more important than others.
#
# Complexity and Training Time: Evaluate the complexity and training time of each model. GRU and LSTM models are typically more complex than simple RNNs, which could result in longer training times. Consider whether the higher accuracy of the GRU model justifies the increased complexity and training time.
#
# Generalization: Assess how well each model generalizes to unseen data. We can also use techniques like cross-validation or holdout validation to evaluate the models on validation or test datasets that were not used during training.
#
# Interpretability: Consider the interpretability of each model. Simple RNNs are easier to interpret than GRU and LSTM models due to their simpler architecture. Based on interpretability a simpler model may be preferable like the RNN.
#
# Resource Constraints: As we've resource constraints on further processing and evaluating a perfect speech recognition model and interpreting the output of the model to use our WER, CER metrics it is imperative to consider the resources available

# %%
# Check the reverse word index
#print("Reverse Word Index:")
#print(reverse_word_index)

# Check the first few sequences
#for i, sequence in enumerate(rnn_predictions[:5]):
    #print(f"Sequence {i}: {sequence}")

# Verify if sequences are mapped to words correctly
#for i, sequence in enumerate(rnn_predictions[:5]):
   # text = ' '.join(reverse_word_index.get(int(idx[0]), '') for idx in sequence)
    #print(f"Predicted Text {i}: {text}")

# %%
# Reverse mapping of word indices to words
# reverse_word_index = {idx: word for word, idx in word_tokenizer.word_index.items()}

# Function to convert word indices to text
# def sequences_to_text(sequences):
   # texts = []
   # for sequence in sequences:
    #    # Convert each element to integer before using it as a key
     #   text = ' '.join(reverse_word_index.get(int(idx[0]), '') for idx in sequence)
      #  texts.append(text)
    #return texts

# Convert predicted sequences to text
# predicted_texts = sequences_to_text(rnn_predictions)
